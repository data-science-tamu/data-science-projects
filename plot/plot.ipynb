# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np

# %%
pred_e = np.loadtxt("../results/pred_E/epoch22.txt").reshape(256,256)
plt.imshow(pred_e)

# %%
pred_v = np.loadtxt("../results/pred_v/epoch23.txt").reshape(256,256)
plt.imshow(pred_v)

# %%
# %matplotlib widget
# Out:
# Warning: Cannot change to a different GUI toolkit: widget. Using notebook instead.

# %%
# Make a movie
fig, ax = plt.subplots()


def f(x, y):
    return np.sin(x) + np.cos(y)

x = np.linspace(0, 2 * np.pi, 120)
y = np.linspace(0, 2 * np.pi, 100).reshape(-1, 1)

# ims is a list of lists, each row is a list of artists to draw in the
# current frame; here we are just animating one artist, the image, in
# each frame
ims = []
for i in range(60):
    x += np.pi / 15
    y += np.pi / 30
    im = ax.imshow(f(x, y), animated=True)
    if i == 0:
        ax.imshow(f(x, y))  # show an initial one first
    ims.append([im])

ani = animation.ArtistAnimation(fig, ims, interval=50, blit=True,
                                repeat_delay=1000)

# To save the animation, use e.g.
# ani.save("movie.mp4")
# writer = animation.FFMpegWriter(
#     fps=15, metadata=dict(artist='Me'), bitrate=1800)
# ani.save("movie.mp4", writer=writer)
plt.show()
# Out:
# <div id='f6249126-4558-4441-b134-f41db9bd06c4'></div>
# c:\Users\Matth\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\animation.py:872: UserWarning: Animation was deleted without rendering anything. This is most likely not intended. To prevent deletion, assign the Animation to a variable, e.g. `anim`, that exists until you output the Animation using `plt.show()` or `anim.save()`.
#   warnings.warn(
