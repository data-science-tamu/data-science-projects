# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib import colormaps
import numpy as np
list(colormaps)
# Out:
# ['magma',
#  'inferno',
#  'plasma',
#  'viridis',
#  'cividis',
#  'twilight',
#  'twilight_shifted',
#  'turbo',
#  'Blues',
#  'BrBG',
#  'BuGn',
#  'BuPu',
#  'CMRmap',
#  'GnBu',
#  'Greens',
#  'Greys',
#  'OrRd',
#  'Oranges',
#  'PRGn',
#  'PiYG',
#  'PuBu',
#  'PuBuGn',
#  'PuOr',
#  'PuRd',
#  'Purples',
#  'RdBu',
#  'RdGy',
#  'RdPu',
#  'RdYlBu',
#  'RdYlGn',
#  'Reds',
#  'Spectral',
#  'Wistia',
#  'YlGn',
#  'YlGnBu',
#  'YlOrBr',
#  'YlOrRd',
#  'afmhot',
#  'autumn',
#  'binary',
#  'bone',
#  'brg',
#  'bwr',
#  'cool',
#  'coolwarm',
#  'copper',
#  'cubehelix',
#  'flag',
#  'gist_earth',
#  'gist_gray',
#  'gist_heat',
#  'gist_ncar',
#  'gist_rainbow',
#  'gist_stern',
#  'gist_yarg',
#  'gnuplot',
#  'gnuplot2',
#  'gray',
#  'hot',
#  'hsv',
#  'jet',
#  'nipy_spectral',
#  'ocean',
#  'pink',
#  'prism',
#  'rainbow',
#  'seismic',
#  'spring',
#  'summer',
#  'terrain',
#  'winter',
#  'Accent',
#  'Dark2',
#  'Paired',
#  'Pastel1',
#  'Pastel2',
# ...

# %%
pred_e = np.loadtxt("../results/pred_E/epoch98.txt").reshape(256,256)
plt.imshow(pred_e)
plt.colorbar()

# %%
pred_e = np.loadtxt("../results/pred_e/epoch99.txt").reshape(256,256)
data_e = np.loadtxt("../data/compressible/m_z5_nu_z11/m_data").reshape(256,256)
plt.imshow(np.abs(pred_e-data_e), cmap='turbo') # 'tab20b'
plt.colorbar()
print(np.mean(np.abs(data_e)), np.mean(np.abs(pred_e-data_e)))
# Out:
# 0.23268759718322757 0.019850821787826625

# %%
pred_v = np.loadtxt("../results/pred_v/epoch98.txt").reshape(256,256)
plt.imshow(pred_v)

# %%
pred_v = np.loadtxt("../results/pred_v/epoch99.txt").reshape(256,256)
data_v = np.loadtxt("../data/compressible/m_z5_nu_z11/nu_data").reshape(256,256)
plt.imshow(np.abs(pred_v-data_v), cmap='turbo') # 'tab20b'
plt.colorbar()
print(np.mean(np.abs(data_v)), np.mean(np.abs(pred_v-data_v)))
# Out:
# 0.16021407814605715 0.055853446928212216

# %%
# Make a movie
fig, ax = plt.subplots()


def f(x, y):
    return np.sin(x) + np.cos(y)

x = np.linspace(0, 2 * np.pi, 120)
y = np.linspace(0, 2 * np.pi, 100).reshape(-1, 1)

# ims is a list of lists, each row is a list of artists to draw in the
# current frame; here we are just animating one artist, the image, in
# each frame
ims = []
for i in range(60):
    x += np.pi / 15
    y += np.pi / 30
    im = ax.imshow(f(x, y), animated=True)
    if i == 0:
        ax.imshow(f(x, y))  # show an initial one first
    ims.append([im])

ani = animation.ArtistAnimation(fig, ims, interval=50, blit=True,
                                repeat_delay=1000)

# To save the animation, use e.g.
# ani.save("movie.mp4")
# writer = animation.FFMpegWriter(
#     fps=15, metadata=dict(artist='Me'), bitrate=1800)
# ani.save("movie.mp4", writer=writer)
plt.show()
# Out:
# <div id='f6249126-4558-4441-b134-f41db9bd06c4'></div>
# c:\Users\Matth\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\animation.py:872: UserWarning: Animation was deleted without rendering anything. This is most likely not intended. To prevent deletion, assign the Animation to a variable, e.g. `anim`, that exists until you output the Animation using `plt.show()` or `anim.save()`.
#   warnings.warn(

# %%
loss = np.loadtxt("../results/loss/m_z5_nu_z11_fitting_loss.txt")
plt.yscale('log')
plt.plot(loss)

# %%
pred_exx = np.loadtxt("../results/pred_exx/fit30.txt").reshape(256,256)
plt.imshow(pred_exx, cmap='viridis')
plt.colorbar()

# %%
pred_eyy = np.loadtxt("../results/pred_eyy/fit49.txt").reshape(256,256)
plt.imshow(pred_eyy, cmap='viridis')
plt.colorbar()

# %%
pred_rxy = np.loadtxt("../results/pred_rxy/fit49.txt").reshape(256,256)
plt.imshow(pred_rxy, cmap='viridis')
plt.colorbar()

# %%
pred_exx = np.loadtxt("../results/pred_exx/fit49.txt").reshape(256,256)
data_exx = np.loadtxt("../data/compressible/m_z5_nu_z11/strain_data")[:,0].reshape(256,256)
plt.imshow(np.abs(pred_exx-data_exx), cmap='turbo') # 'tab20b'
plt.colorbar()
print(np.mean(np.abs(data_exx)), np.mean(np.abs(pred_exx-data_exx)))
# Out:
# 0.9999999999999999 0.0068803182779684354

# %%
pred_eyy = np.loadtxt("../results/pred_eyy/fit49.txt").reshape(256,256)
data_eyy = np.loadtxt("../data/compressible/m_z5_nu_z11/strain_data")[:,1].reshape(256,256)
plt.imshow(np.abs(pred_eyy-data_eyy), cmap='turbo') # 'tab20b'
plt.colorbar()
print(np.mean(np.abs(data_eyy)), np.mean(np.abs(pred_eyy-data_eyy)))
# Out:
# 0.17093698768615723 0.019180705202558802

# %%
pred_rxy = np.loadtxt("../results/pred_rxy/fit49.txt").reshape(256,256)
data_rxy = np.loadtxt("../data/compressible/m_z5_nu_z11/strain_data")[:,2].reshape(256,256)
plt.imshow(np.abs(pred_rxy-data_rxy), cmap='turbo') # 'tab20b'
plt.colorbar()
print(np.mean(np.abs(data_exx)), np.mean(np.abs(pred_exx-data_exx)))
# Out:
# 0.15661235719299316 1.0245916190020323
